# %%
import cv2
import numpy as np
from ultralytics import YOLO
from Tracker3 import ObjectCounter  # Importing ObjectCounter from tracker.py

# %%
puntos = []
ruta = "4_abr_2020_1729.mp4"
video_iniciado = False  # Para controlar cuándo empieza el video

def seleccionar_puntos(event, x, y, flags, param):
    global puntos, video_iniciado

    if event == cv2.EVENT_LBUTTONDOWN:  # Si se hace clic izquierdo
        puntos.append((x, y))  # Agregar el punto a la lista

        # Dibujar el punto en la imagen
        #cv2.circle(imagen, (x, y), 5, (0, 255, 0), -1)  # Poner un círculo verde en el punto

        if len(puntos) == 2:  # Si ya se han seleccionado 2 puntos
            # Dibujar la línea entre los dos puntos
            #cv2.line(imagen, puntos[0], puntos[1], (0, 0, 255), 2)  # Línea roja
            
            cv2.imshow("nombrepestania", imagen)
            #video_iniciado = True  # El video puede comenzar ahora


# Open the video file
cap = cv2.VideoCapture(ruta) #### esto se cambia


# Leer el primer frame del video
ret, imagen = cap.read()
imagen = cv2.resize(imagen, (1020, 500))

if not ret:
    print("No se pudo leer el primer frame del video")
    exit()

cv2.imshow("nombrepestania", imagen)
cv2.setMouseCallback("nombrepestania", seleccionar_puntos)


# Define region points for counting


# Esperar hasta que el usuario seleccione los dos puntos
while len(puntos) < 2:
    # Check if the window was closed with the 'x' button
    if cv2.getWindowProperty("nombrepestania", cv2.WND_PROP_VISIBLE) < 1:
        break
    key = cv2.waitKey(1)
    if key == 27:  # ESC key to exit
        break



# Reproducir el video después de seleccionar los dos puntos


count = 0

region_points = [puntos[0], puntos[1]]

# Initialize the object counter
counter = ObjectCounter(
    nombre_archivo = ruta,
    region=region_points,  # Pass region points
    model = "yolo11s.pt",
    #device='gpu',# ="yolo11s.pt",  # Model for object counting
    classes=[0,2,3,5,7],  # Detect only person class
    show_in=True,  # Display in counts
    show_out=True,  # Display out counts
    line_width=2,  # Adjust line width for display
    )

while True:
    
    
    ret, imagen = cap.read()

    #imagen = cv2.resize(imagen, (1020, 500))

    # Si no se puede leer el frame, salir del bucle
    if not ret:
        break

    count += 1
    if count % 2 != 0:  # Skip odd frames
        continue

    imagen = cv2.resize(imagen, (1020, 500))

    #imagen = cv2.resize(imagen, (1020, 500))

    # Process the frame with the object counter
    imagen = counter.count(imagen)

    # Mostrar el frame actual
    cv2.imshow("nombrepestania", imagen)

    # Salir si presionas la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object and close the display window


cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-03-19 16:03:04.389 python[12532:10603345] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-19 16:03:04.389 python[12532:10603345] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# Ultralytics Solutions: ✅ {'region': [(4, 370), (1015, 293)], 'show_in': True, 'show_out': True, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'model': 'yolo11s.pt', 'classes': [0, 2, 3, 5, 7], 'line_width': 2}
# CSV file created: 4_abr_2020_1729.mp4_vehicle_count_data_.csv with headers.
#
# 0: 320x640 7 cars, 3 buss, 2 trucks, 96.9ms
# Speed: 3.1ms preprocess, 96.9ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2
ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 92.0ms
# Speed: 1.9ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 80.9ms
# Speed: 2.1ms preprocess, 80.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 88.6ms
# Speed: 1.6ms preprocess, 88.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 87.5ms
# Speed: 2.1ms preprocess, 87.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 94.5ms
# Speed: 2.2ms preprocess, 94.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 91.7ms
# Speed: 3.0ms preprocess, 91.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 87.4ms
# Speed: 2.4ms preprocess, 87.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 87.1ms
# Speed: 2.1ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 78.7ms
# Speed: 3.2ms preprocess, 78.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 1 truck, 81.2ms
# Speed: 1.4ms preprocess, 81.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 75.8ms
# Speed: 1.6ms preprocess, 75.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 1 truck, 78.4ms
# Speed: 2.0ms preprocess, 78.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 1 truck, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 1 truck, 77.5ms
# Speed: 1.2ms preprocess, 77.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 81.7ms
# Speed: 1.9ms preprocess, 81.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 108.5ms
# Speed: 3.5ms preprocess, 108.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 79.4ms
# Speed: 1.7ms preprocess, 79.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 182 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 14 cars, 74.6ms
# Speed: 2.9ms preprocess, 74.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 78.4ms
# Speed: 2.1ms preprocess, 78.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 76.8ms
# Speed: 23.3ms preprocess, 76.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 217 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
# Data for track_id 220 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 12 cars, 79.6ms
# Speed: 1.4ms preprocess, 79.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 71.7ms
# Speed: 1.6ms preprocess, 71.7ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 86.6ms
# Speed: 1.7ms preprocess, 86.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 82.7ms
# Speed: 1.4ms preprocess, 82.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 218 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 12 cars, 74.9ms
# Speed: 1.9ms preprocess, 74.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 93.8ms
# Speed: 2.4ms preprocess, 93.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 78.1ms
# Speed: 1.5ms preprocess, 78.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 219 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 14 cars, 78.2ms
# Speed: 2.1ms preprocess, 78.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 83.6ms
# Speed: 1.6ms preprocess, 83.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 85.3ms
# Speed: 2.6ms preprocess, 85.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15 cars, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15 cars, 84.3ms
# Speed: 2.4ms preprocess, 84.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15 cars, 87.5ms
# Speed: 1.4ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15 cars, 87.6ms
# Speed: 1.3ms preprocess, 87.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 80.1ms
# Speed: 1.6ms preprocess, 80.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 86.8ms
# Speed: 1.8ms preprocess, 86.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 92.7ms
# Speed: 2.0ms preprocess, 92.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 89.2ms
# Speed: 1.7ms preprocess, 89.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 90.1ms
# Speed: 1.7ms preprocess, 90.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 116.7ms
# Speed: 1.6ms preprocess, 116.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 195 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 14 cars, 69.8ms
# Speed: 1.7ms preprocess, 69.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 76.9ms
# Speed: 4.4ms preprocess, 76.9ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 69.0ms
# Speed: 1.7ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 75.0ms
# Speed: 2.1ms preprocess, 75.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14 cars, 77.5ms
# Speed: 1.6ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars, 76.1ms
# Speed: 1.4ms preprocess, 76.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13 cars,
ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 81.6ms
# Speed: 2.8ms preprocess, 81.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 105.8ms
# Speed: 1.5ms preprocess, 105.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 136.4ms
# Speed: 1.7ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 106.7ms
# Speed: 2.3ms preprocess, 106.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 1 bus, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 1 bus, 102.9ms
# Speed: 1.9ms preprocess, 102.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 435 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 11 cars, 1 motorcycle, 1 bus, 73.8ms
# Speed: 1.5ms preprocess, 73.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 motorcycle, 1 bus, 81.1ms
# Speed: 1.7ms preprocess, 81.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 81.3ms
# Speed: 1.5ms preprocess, 81.3ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 75.5ms
# Speed: 2.4ms preprocess, 75.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 bus, 78.7ms
# Speed: 1.5ms preprocess, 78.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 150.6ms
# Speed: 1.5ms preprocess, 150.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 91.2ms
# Speed: 2.0ms preprocess, 91.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 74.6ms
# Speed: 1.5ms preprocess, 74.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 bus, 93.2ms
# Speed: 1.5ms preprocess, 93.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 1 truck, 97.5ms
# Speed: 1.5ms preprocess, 97.5ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 71.6ms
# Speed: 1.5ms preprocess, 71.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 100.6ms
# Speed: 1.5ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10 cars, 1 truck, 144.9ms
# Speed: 1.7ms preprocess, 144.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# Data for track_id 433 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
# Data for track_id 438 saved to CSV file 4_abr_2020_1729.mp4_vehicle_count_data_.csv.
#
# 0: 320x640 1 person, 11 cars, 1 truck, 88.2ms
# Speed: 2.2ms preprocess, 88.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 85.3ms
# Speed: 2.3ms preprocess, 85.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 74.3ms
# Speed: 1.4ms preprocess, 74.3ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 72.4ms
# Speed: 1.4ms preprocess, 72.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 75.3ms
# Speed: 1.3ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12 cars, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 87.5ms
# Speed: 2.2ms preprocess, 87.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 95.2ms
# Speed: 3.1ms preprocess, 95.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11 cars, 84.7ms
# Speed: 2.9ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 109.5ms
# Speed: 1.8ms preprocess, 109.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 82.5ms
# Speed: 1.4ms preprocess, 82.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 cars, 81.5ms
# Speed: 1.4ms preprocess, 81.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 79.8ms
# Speed: 1.5ms preprocess, 79.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 93.3ms
# Speed: 1.6ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 79.2ms
# Speed: 2.0ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 1 truck, 94.2ms
# Speed: 1.7ms preprocess, 94.2ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 84.4ms
# Speed: 2.9ms preprocess, 84.4ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 cars, 1 truck, 83.7ms
# Speed: 2.0ms preprocess, 83.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 cars, 71.1ms
# Speed: 1.5ms preprocess, 71.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 cars, 84.9ms
# Speed: 1.8ms preprocess, 84.9ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch

torch.cuda.is_available()
#True

#>>> torch.cuda.device_count()

# torch.cuda.current_device()
# Out:
# False
